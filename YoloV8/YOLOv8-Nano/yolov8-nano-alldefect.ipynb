# %%
# !nvidia-smi
# Out:
# Mon Sep 18 14:49:13 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla T4            Off  | 00000000:00:05.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /kaggle/working

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 15.6 GB RAM, 5016.7/8062.4 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet


from roboflow import Roboflow
rf = Roboflow(api_key="1XSyo44Ff6sz3vS6IsPe")
project = rf.workspace("angelolmg").project("mixed-textile-defects")
dataset = project.version(1).download("yolov8")
# Out:
# /kaggle/working/datasets
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-lsp 4.2.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# pytoolconfig 1.2.5 requires packaging>=22.0, but you have packaging 21.3 which is incompatible.
# ydata-profiling 4.3.1 requires scipy<1.11,>=1.4.1, but you have scipy 1.11.2 which is incompatible.
# A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.20, to fix: `pip install ultralytics==8.0.134`
# Downloading Dataset Version Zip in mixed-textile-defects-1 to yolov8:: 100%|██████████| 756829/756829 [00:13<00:00, 55026.99it/s]
# Extracting Dataset Version Zip to mixed-textile-defects-1 in yolov8:: 100%|██████████| 9024/9024 [00:02<00:00, 3949.67it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=100 imgsz=1024 plots=True
# Out:
# /kaggle/working
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 71.5MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8n.yaml, data=/kaggle/working/datasets/mixed-textile-defects-1/data.yaml, epochs=100, patience=50, batch=16, imgsz=1024, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 13.3MB/s]
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.Detect                [1, [64, 128, 256]]
# Model summary: 225 layers, 3011043 parameters, 3011027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /kaggle/working/datasets/mixed-textile-defects-1/train/labels...
# train: New cache created: /kaggle/working/datasets/mixed-textile-defects-1/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/working/datasets/mixed-textile-defects-1/valid/labels... 3
# val: New cache created: /kaggle/working/datasets/mixed-textile-defects-1/valid/labels.cache
# Image sizes 1024 train, 1024 val
# Using 1 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100       6.1G      2.368        4.1       2.17          9       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.414      0.209        0.2     0.0722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      7.11G      2.147      2.777      1.921         16       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.413      0.289      0.271      0.107
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      7.12G      2.182      2.667      1.964          4       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464       0.25     0.0733      0.048     0.0163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      7.12G      2.211      2.609      2.022          9       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.251      0.321      0.213     0.0787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      7.13G      2.177      2.547      2.004          6       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.515      0.378      0.379      0.143
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      7.13G      2.072      2.369      1.949          8       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.546      0.288      0.292      0.121
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      7.13G      2.005      2.262      1.908         11       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.516      0.356      0.364      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      7.13G      1.968      2.222      1.883         10       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.533        0.3      0.275      0.114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      7.13G      1.931      2.096      1.831         13       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464       0.53      0.487      0.503       0.23
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      7.13G      1.894      2.063      1.826          9       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.639       0.47      0.556      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      7.13G      1.861      1.993      1.782          8       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.599      0.498      0.513      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      7.13G      1.833      1.934      1.762         17       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.506      0.308      0.309      0.129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      7.13G      1.829      1.908       1.75          7       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.653      0.369      0.402      0.183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      7.13G      1.803      1.854      1.745         14       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.589      0.394      0.432      0.197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      7.13G      1.766      1.817      1.728          8       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.642      0.391      0.441      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      7.13G      1.729      1.776      1.713         13       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.633      0.399      0.446       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      7.13G      1.706      1.759      1.675         13       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.522      0.289      0.277      0.129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      7.13G      1.704       1.72      1.655         15       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.722      0.576      0.643      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      7.13G      1.671      1.668      1.648         13       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.713      0.606      0.656      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      7.13G      1.666      1.661      1.633         18       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.662      0.562      0.605      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      7.13G      1.666      1.665      1.639          6       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.617      0.344      0.395      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      7.13G      1.651      1.639      1.623         10       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.632      0.574      0.608      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      7.13G      1.626      1.592      1.604          8       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.697      0.608      0.668       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      7.13G      1.619      1.604       1.59          6       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.672      0.634      0.678       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      7.13G        1.6       1.57      1.588         10       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.642      0.606      0.642      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      7.13G      1.564      1.522      1.573         13       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.718      0.612      0.678      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      7.13G      1.559      1.509      1.555         12       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0
1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.865      0.775      0.845      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      7.13G       1.06      0.916      1.201         11       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464       0.84      0.767      0.834      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      7.13G      1.054     0.9033      1.199         12       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.865      0.774       0.84      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      7.13G      1.051     0.9093      1.196         14       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.851      0.761      0.837      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      7.13G      1.059     0.8945      1.202         10       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.857      0.778      0.838      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      7.13G      1.049     0.8962      1.196          6       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.855      0.752      0.828      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      7.13G       1.04      0.887      1.194          8       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.839      0.795      0.832      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      7.13G      1.022     0.8672      1.176         12       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.881      0.761      0.848      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      7.13G      1.028      0.868      1.178         10       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.876      0.761       0.84      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      7.13G      1.015     0.8475      1.177          9       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464       0.88      0.759      0.849      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      7.13G      1.013     0.8637       1.17         14       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.872      0.767      0.849      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      7.13G      1.002     0.8434      1.161          9       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.865      0.778      0.849      0.533
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      7.13G     0.9639     0.7111      1.141          6       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.847      0.808      0.862      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      7.13G      0.925     0.6901      1.121          7       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.842      0.806      0.862      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      7.13G     0.9223     0.6824      1.124          5       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.832      0.789       0.84      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      7.13G     0.9007     0.6615      1.106          7       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.859       0.78       0.86      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      7.13G     0.9026     0.6623      1.104          6       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.853      0.804      0.859      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      7.13G     0.8818     0.6574      1.103          6       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.844      0.795      0.851      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      7.13G     0.8668     0.6395      1.086          9       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.847      0.804      0.857      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      7.13G      0.871     0.6354      1.087          6       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.817      0.819      0.857      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      7.13G     0.8564     0.6403      1.083          7       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.875       0.77      0.855      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      7.13G     0.8545     0.6256      1.083          7       1024: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464      0.879      0.763      0.856      0.543
#
# 100 epochs completed in 9.918 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.3MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.3MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464       0.88      0.769      0.855      0.546
# Speed: 4.8ms pre-process, 6.4ms inference, 0.0ms loss, 2.2ms post-process per image
# Results saved to runs/detect/train

# %%
# !ls {HOME}/runs/detect/train
# Out:
# F1_curve.png					  train_batch2.jpg
# PR_curve.png					  train_batch22230.jpg
# P_curve.png					  train_batch22231.jpg
# R_curve.png					  train_batch22232.jpg
# args.yaml					  val_batch0_labels.jpg
# confusion_matrix.png				  val_batch0_pred.jpg
# events.out.tfevents.1695048789.4ef322bfb4e3.88.0  val_batch1_labels.jpg
# results.csv					  val_batch1_pred.jpg
# results.png					  val_batch2_labels.jpg
# train_batch0.jpg				  val_batch2_pred.jpg
# train_batch1.jpg				  weights

# %%
# %cd {HOME}
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml plots=True
# Out:
# /kaggle/working
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /kaggle/working/datasets/mixed-textile-defects-1/valid/labels.cach
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        376        464       0.86      0.784      0.855      0.548
# Speed: 3.0ms pre-process, 9.1ms inference, 0.0ms loss, 1.7ms post-process per image

# %%
# !ls {HOME}/runs/detect/val
# Out:
# F1_curve.png  confusion_matrix.png   val_batch1_pred.jpg
# PR_curve.png  val_batch0_labels.jpg  val_batch2_labels.jpg
# P_curve.png   val_batch0_pred.jpg    val_batch2_pred.jpg
# R_curve.png   val_batch1_labels.jpg

# %%
import zipfile

# Diretório que você deseja compactar
diretorio_a_compactar = '/kaggle/working/runs/detect/val'

# Nome do arquivo ZIP resultante
nome_arquivo_zip = 'val.zip'

# Compacta o diretório em um arquivo ZIP
with zipfile.ZipFile(nome_arquivo_zip, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(diretorio_a_compactar):
        for file in files:
            zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), diretorio_a_compactar))

# Cria um link para download do arquivo ZIP
from IPython.display import FileLink
FileLink(nome_arquivo_zip)
# Out:
# /kaggle/working/val.zip
